# %%
#!pip install opencv-python

# %%
#!pip install experta

# %%
from experta import *
from tkinter import *  # import de tkinter
from tkinter import ttk 
import tkinter as tk
from PIL import ImageTk, Image

# %%
def action(event):
    # Obtenir l'élément sélectionné
    print("Valeur change")
root =Tk()
root.title("Bienvenue") # titre de l'interface
#root.minsize(1220, 660)
width= root.winfo_screenwidth()
height= root.winfo_screenheight()
#setting tkinter window size
root.geometry("%dx%d" % (width, height))
#root.config(background='#048B94')  
#---------code image bacground------
root.configure(bg = "#ffffff")
canvas = Canvas(
        root,
        bg = "#ffffff",
        height = 660,
        width = 1220,
        bd = 0,
        highlightthickness = 0,
        relief = "ridge")
canvas.place(x = 0, y = 0)
background_img = PhotoImage(file="image/orientation_bac1.png")
background = canvas.create_image(680, 330,image=background_img)



#-----------------------titre -------------------------    

obj =Label(root,text=" BIENVENUE A NOTRE APPLICATION WAJAHNI",font=("Courrier", 20),bg="#fcfefe",fg='black')
obj.pack()

#--------------------------section----------------------------------------------
frame1 = Frame(root,bg="#131346")
frame1.place(x=50,y=100)
obj1 =Label(frame1,text="Choisir votre section: ",font=("Courrier", 20),bg="#F4BFBF",fg='white')
obj1.grid(row = 0, column = 0, sticky = W, pady = 1)
# 2) - créer la liste Python contenant les éléments de la liste Combobox
listeSection=["Mathematique", "Sciences Expérimentales","Economie et Gestion","Sciences Techniques","Lettres","Informatique","Education Physique"]
# 3) - Création de la Combobox via la méthode ttk.Combobox()
SectionCombo = ttk.Combobox(frame1, values=listeSection)
# 4) - Choisir l'élément qui s'affiche par défaut
SectionCombo.current(0)
SectionCombo.grid(row = 1, column = 0, sticky='nesw', pady = 1)
SectionCombo.bind("<<ComboboxSelected>>",action)



#--------------------------score----------------------------------------------
frame2 = Frame(root,bg="#131346")
frame2.place(x=1000,y=100)
obj2 =Label(frame2,text="Choisir votre score:",font=("Courrier", 20),bg='#488b8f',fg='white')
obj2.grid(row = 0, column = 0, sticky = W, pady = 1)
listeScore=["entre 70 et 100", "entre 100 et 130", "entre 130 et 160","supérieur à 160"]
ScoreCombo = ttk.Combobox(frame2, values=listeScore,height=10)
ScoreCombo.current(0)
ScoreCombo.grid(row = 1, column = 0, sticky='nesw', pady = 1)
ScoreCombo.bind("<<ComboboxSelected>>",action)


#--------------------------Categorie----------------------------------------------
frame3 = Frame(root,bg="#131346")
frame3.place(x=50,y=260)
obj3 =Label(frame3,text="Choisir la catégorie souhaitée: : ",font=("Courrier", 20),bg='#FFB533',fg='white')
obj3.grid(row = 0, column = 0, sticky = W, pady = 1)
listeCategorie=["Tunis","Tunis Manar","Carthage","Sfax","Monastir","Gabes","Sousse","Gafsa","Manouba","Beja","Zaghouan","Nabeul"]
CategorieCombo = ttk.Combobox(frame3, values=listeCategorie)
CategorieCombo.current(0)
CategorieCombo.grid(row = 1, column = 0, sticky='nesw', pady = 1)
CategorieCombo.bind("<<ComboboxSelected>>",action)

#--------------------------Domaine----------------------------------------------
frame4 = Frame(root,bg="#131346")
frame4.place(x=1000,y=260)
obj4 =Label(frame4,text="Choisir le domaine souhaité: ",font=("Courrier", 20),bg='#7cbd1e',fg='white')
obj4.grid(row = 0, column = 0, sticky = W, pady = 1)
listeDomaine=["Lettres,Langues et Cycles Préparatoires Littéraires",
              "Sciences Humaines,Sociales,Théologique et Education", 
              "Tourisme,Animation,Sport et Education physique",
              "Culture,Beaux-Arts et Métiers",
              "Sciences Juridiques et Sciences Politiques",
             "Sciences Economiques et Sciences de Gestion",
              "Sciences Exactes et Technologies",
              "Architecture et Cycles Préparatoires aux études d’Ingénieurs",
             "Sciences de la santé,Médecine ,Médecine dentaire et Pharmacie",
              "Sciences Agronomiques,Biotechnologie et Environnement",
              "Education et Pédagogie"]
DomaineCombo = ttk.Combobox(frame4, values=listeDomaine)
DomaineCombo.current(0)
DomaineCombo.grid(row = 1, column = 0, sticky='nesw', pady = 1)
DomaineCombo.bind("<<ComboboxSelected>>",action)

#--------------------------Régime----------------------------------------------
frame5 = Frame(root,bg="#131346")
frame5.place(x=540,y=550)
obj5 =Label(frame5,text="Entrer le régime souhaité: ",font=("Courrier", 20),bg='#9A86A4',fg='white')
obj5.grid(row = 0, column = 0, sticky = W, pady = 1)
listeRegime=["LMD", "Préparatoire"]
RegimeCombo = ttk.Combobox(frame5, values=listeRegime)
RegimeCombo.current(0)
RegimeCombo.grid(row = 1, column = 0, sticky='nesw', pady = 1)
RegimeCombo.bind("<<ComboboxSelected>>",action)
#--------------------------Sexe----------------------------------------------
frame6 = Frame(root,bg="#131346")
frame6.place(x=1000,y=460)
obj6 =Label(frame6,text="Choisir votre sexe: ",font=("Courrier", 20),bg='#cb3737',fg='white')
obj6.grid(row = 0, column = 0, sticky = W, pady = 1)
listeSexe=["Masculin", "Feminin"]
SexeCombo = ttk.Combobox(frame6, values=listeSexe)
SexeCombo.current(0)
SexeCombo.grid(row = 1, column = 0, sticky='nesw', pady = 1)
SexeCombo.bind("<<ComboboxSelected>>",action)

#--------------------------Age----------------------------------------------
frame7 = Frame(root,bg="#131346")
frame7.place(x=50,y=460)
obj7 =Label(frame7,text="Choisir votre age: ",font=("Courrier", 20),bg='#f76b8a',fg='white')
obj7.grid(row = 0, column = 0, sticky = W, pady = 1)
listeAge=["18 ans", "19 ans"]
AgeCombo = ttk.Combobox(frame7, values=listeAge)
AgeCombo.current(0)
AgeCombo.grid(row = 1, column = 0, sticky='nesw', pady = 1)
AgeCombo.bind("<<ComboboxSelected>>",action)
# Out:
# '1792358365376action'

# %%
#-------------------BUTTUON------------------------------------------------------

def function_traitement():
    root1 =Toplevel()
    root1.title("Résultat") # titre de l'interface
    root1.minsize(300,300)
    root1.configure(bg = "#ffffff")
    canvas1 = Canvas(
                    root1,
                    bg = "#ffffff",
                    height = 660,
                    width = 1220,
                    bd = 0,
                    highlightthickness = 0,
                    relief = "ridge")
    canvas1.place(x = 0, y = 0)
   
    #-----recuperation contenu de variable section----
    def section_function(SectionCombo):
        if SectionCombo.get()=="Mathematique" :
            section='Mathematique'
        if SectionCombo.get()=="Sciences Expérimentales" :
            section='Sciences Expérimentales'
        if SectionCombo.get()=="Economie et Gestion" :
            section='Economie et Gestion'
        if SectionCombo.get()=="Sciences Techniques" :
            section='Sciences Techniques'
        if SectionCombo.get()=="Education Physique" :
            section='Education Physique'
        if SectionCombo.get()=="Lettres" :
            section='Lettres'
        if SectionCombo.get()=="Informatique" :
            section='Informatique'    
        return section
     #-----recuperation contenu de variable score----
    def score_function(ScoreCombo):   
        if ScoreCombo.get()=="entre 70 et 100" :
            score='entre 70 et 100'
        if ScoreCombo.get()=="entre 100 et 130" :
            score='entre 100 et 130'
        if ScoreCombo.get()=="entre 130 et 160" :
            score='entre 100 et 130'
        if ScoreCombo.get()=="supérieur à 160" :
            score='supérieur à 160'
        return score
     #-----recuperation contenu de variable categorie----
    def lieu_function(CategorieCombo): 
        if CategorieCombo.get()=="Tunis" :
            Categorie='tunis'
        if CategorieCombo.get()=="Tunis Manar" :
            Categorie='Tunis Manar'
        if CategorieCombo.get()=="Carthage" :
            Categorie='Carthage'
        if CategorieCombo.get()=="Sfax" :
            Categorie='Sfax'
        if CategorieCombo.get()=="Monastir" :
            Categorie='Monastir'
        if CategorieCombo.get()=="Gabes" :
            Categorie='Gabes'
        if CategorieCombo.get()=="Monastir" :
            Categorie='Monastir'
        if CategorieCombo.get()=="Gafsa" :
            Categorie='Gafsa'
        if CategorieCombo.get()=="Manouba" :
            Categorie='Manouba'
        if CategorieCombo.get()=="Beja" :
            Categorie='Beja'
        if CategorieCombo.get()=="Sousse" :
            Categorie='Sousse'
        if CategorieCombo.get()=="Zaghouan":   
            Categorie="Zaghouan"
        if CategorieCombo.get()=="Nabeul":   
            Categorie="Nabeul"    
        return Categorie
     #-----recuperation contenu de variable domaine----
    def domaine_function(DomaineCombo): 
        if DomaineCombo.get()=="Lettres,Langues et Cycles Préparatoires Littéraires" :
            Domaine='Lettres,Langues et Cycles Préparatoires Littéraires'
        if DomaineCombo.get()=="Sciences Humaines,Sociales,Théologique et Education" :
            Domaine='Sciences Humaines,Sociales,Théologique et Education'
        if DomaineCombo.get()=="Tourisme,Animation,Sport et Education physique" :
            Domaine='Tourisme,Animation,Sport et Education physique'
        if DomaineCombo.get()=="Culture,Beaux-Arts et Métiers" :
            Domaine='Culture,Beaux-Arts et Métiers'
        if DomaineCombo.get()=="Sciences Juridiques et Sciences Politiques" :
            Domaine='Sciences Juridiques et Sciences Politiques'
        if DomaineCombo.get()=="Sciences Economiques et Sciences de Gestion" :
            Domaine='Sciences Economiques et Sciences de Gestion'
        if DomaineCombo.get()=="Sciences Exactes et Technologies" :
            Domaine='Sciences Exactes et Technologies'
        if DomaineCombo.get()=="Architecture et Cycles Préparatoires aux études d’Ingénieurs" :
            Domaine='Architecture et Cycles Préparatoires aux études d’Ingénieurs'
        if DomaineCombo.get()=="Sciences de la santé,Médecine ,Médecine dentaire et Pharmacie" :
            Domaine='Sciences de la santé,Médecine ,Médecine dentaire et Pharmacie'
        if DomaineCombo.get()=="Sciences Agronomiques,Biotechnologie et Environnement" :
            Domaine='Sciences Agronomiques,Biotechnologie et Environnement'
        if DomaineCombo.get()=="Education et Pédagogie":
            Domaine="Education et Pédagogie"
        return Domaine
     #-----recuperation contenu de variable regime----
    def regime_function(RegimeCombo): 
        if RegimeCombo.get()=="LMD" :
            regime='LMD'
        if RegimeCombo.get()=="Préparatoire" :
            regime='Préparatoire'
        return regime
    #-----recuperation contenu de variable sexe ----
    def sexe_function(SexeCombo): 
        if SexeCombo.get()=="Masculin" :
            sexe='Masculin'
        if SexeCombo.get()=="Feminin" :
            sexe='Feminin'
        return sexe
     #-----recuperation contenu de variable age ----
    def age_function(AgeCombo): 
        if AgeCombo.get()=="18 ans" :
            age='18 ans'
        if AgeCombo.get()=="19 ans" :
            age='19 ans'
        return age
    
    #---------------------------------
    class tawjih(KnowledgeEngine):
        FSection=""
        FScore=""
        FRegime=""
        FDomaine=""
        FCategorie=""
        FSexe=""
        FAge=""
        test=False
        
        
        
        #fonction our initialisation
        @DefFacts() 
        def _initial_action(self):
            yield Fact(action="universite")
            
   
        # fonction pour get valeur de section
        @Rule(Fact(action='universite'),NOT(Fact(FSection)))
        def ObtainFaitSection(self):
            self.declare(Fact(FSection=section_function(SectionCombo)))
            

        # fonction pour get valeur de score
        @Rule(Fact(action='universite'),NOT(Fact(FScore)))
        def ObtainFaitScore(self):
            self.declare(Fact(FScore=score_function(ScoreCombo)))
        
        # fonction pour get valeur de categorie
        @Rule(Fact(action='universite'),NOT(Fact(FCategorie)))
        def ObtainFaitCategory(self):
            self.declare(Fact(FCategorie=lieu_function(CategorieCombo)))                
            

        @Rule(Fact(action='universite'),NOT(Fact(FDomaine)))
        def ObtainFaitDomaine(self):
            self.declare(Fact(FDomaine=domaine_function(DomaineCombo)))
            

        @Rule(Fact(action='universite'),NOT(Fact(FRegime)))
        def ObtainFaitRegime(self):
            self.declare(Fact(FRegime=regime_function(RegimeCombo)))
            
        @Rule(Fact(action='universite'),NOT(Fact(FSexe)))
        def ObtainFaitSexe(self):
            self.declare(Fact(FSexe=sexe_function(SexeCombo)))
            
        @Rule(Fact(action='universite'),NOT(Fact(FAge)))
        def ObtainFaitAge(self):
            self.declare(Fact(FAge=age_function(AgeCombo)))
            
    
            
        #-----BASE DES REGLES-----    
        @Rule(AND(Fact(FSection='Lettres'),
              Fact(FScore='entre 70 et 100'),
              Fact(FCategorie='Manouba'),
              Fact(FDomaine='Lettres,Langues et Cycles Préparatoires Littéraires'),
              Fact(FRegime='LMD'),
              OR(Fact(FSexe='Masculin'),Fact(FSexe='Feminin')),
              OR(Fact(FAge='18 ans'),Fact(FAge='19 ans'))))
        def trouv_faculte1(self):
            test=True
            img = PhotoImage(file="image/fac_lettre_manouba.PNG")
            background= canvas1.create_image(160, 160,image=img)
            root1.mainloop() 
            
        @Rule(AND(Fact(FSection='Lettres'),
              Fact(FScore='entre 100 et 130'),
              Fact(FCategorie='Sousse'),
              Fact(FDomaine='Sciences Humaines,Sociales,Théologique et Education'),
              Fact(FRegime='LMD'),
              OR(Fact(FSexe='Masculin'),Fact(FSexe='Feminin')),
              OR(Fact(FAge='18 ans'),Fact(FAge='19 ans'))))
        def trouv_faculte2(self):
            test=True
            img = PhotoImage(file="image/fac_science humain_soussa.png")
            background= canvas1.create_image(160, 160,image=img)
            root1.mainloop()  
            
        @Rule(AND(Fact(FSection='Education Physique'),
              Fact(FScore='entre 70 et 100'),
              Fact(FCategorie='Sfax'),
              Fact(FDomaine='Tourisme,Animation,Sport et Education physique'),
              Fact(FRegime='LMD'),
              OR(Fact(FSexe='Masculin'),Fact(FSexe='Feminin')),
              OR(Fact(FAge='18 ans'),Fact(FAge='19 ans'))))
        def trouv_faculte3(self):
            test=True
            img = PhotoImage(file="image/sport.PNG")
            background= canvas1.create_image(160, 160,image=img)
            root1.mainloop()   
            
        @Rule(AND(Fact(FSection='Lettres'),
              Fact(FScore='entre 70 et 100'),
              Fact(FCategorie='Gabes'),
              Fact(FDomaine='Sciences Juridiques et Sciences Politiques'),
              Fact(FRegime='LMD'),
              OR(Fact(FSexe='Masculin'),Fact(FSexe='Feminin')),
              OR(Fact(FAge='18 ans'),Fact(FAge='19 ans'))))
        def trouv_faculte5(self):
            test=True
            img = PhotoImage(file="image/etude_juredique_gabes.png")
            background= canvas1.create_image(160, 160,image=img)
            root1.mainloop()  
            
        @Rule(AND(Fact(FSection='Economie et Gestion'),
              Fact(FScore='entre 130 et 160'),
              Fact(FCategorie='Tunis'),
              Fact(FDomaine='Sciences Economiques et Sciences de Gestion'),
              Fact(FRegime='LMD'),
              OR(Fact(FSexe='Masculin'),Fact(FSexe='Feminin')),
              OR(Fact(FAge='18 ans'),Fact(FAge='19 ans'))))
        def trouv_faculte6(self):
            test=True
            img = PhotoImage(file="image/isg.PNG")
            background= canvas1.create_image(160, 160,image=img)
            root1.mainloop()   
            
        @Rule(AND(Fact(FSection='Economie et Gestion'),
              Fact(FScore='supérieur à 160'),
              Fact(FCategorie='Carthage'),
              Fact(FDomaine='Sciences Economiques et Sciences de Gestion'),
              Fact(FRegime='LMD'),
              OR(Fact(FSexe='Masculin'),Fact(FSexe='Feminin')),
              OR(Fact(FAge='18 ans'),Fact(FAge='19 ans'))))
        def trouv_faculte7(self):
            test=True
            img = PhotoImage(file="image/IHEC_TUNIS.png")
            background= canvas1.create_image(160, 160,image=img)
            root1.mainloop()  
            
        @Rule(AND(OR(Fact(FSection='Mathematique'),Fact(FSection='Sciences Expérimentales')),
              Fact(FScore='entre 130 et 160'),
              Fact(FCategorie='Tunis Manar'),
              Fact(FDomaine='Architecture et Cycles Préparatoires aux études d’Ingénieurs'),
              Fact(FRegime='Préparatoire'),
              OR(Fact(FSexe='Masculin'),Fact(FSexe='Feminin')),
              OR(Fact(FAge='18 ans'),Fact(FAge='19 ans'))))
        def trouv_faculte8(self):
            test=True
            img = PhotoImage(file="image/ipet.PNG")
            background= canvas1.create_image(160, 160,image=img)
            root1.mainloop() 
            
        @Rule(AND(OR(Fact(FSection='Mathematique'),Fact(FSection='Sciences Expérimentales')),
              Fact(FScore='entre 130 et 160'),
              Fact(FCategorie='Tunis Manar'),
              Fact(FDomaine='Sciences Exactes et Technologies'),
              Fact(FRegime='LMD'),
              OR(Fact(FSexe='Masculin'),Fact(FSexe='Feminin')),
              OR(Fact(FAge='18 ans'),Fact(FAge='19 ans'))))
        def trouv_faculte9(self):
            test=True
            img = PhotoImage(file="image/isi.PNG")
            background= canvas1.create_image(160, 160,image=img)
            root1.mainloop() 
            
        @Rule(AND(OR(Fact(FSection='Mathematique'),Fact(FSection='Sciences Expérimentales')),
              Fact(FScore='supérieur à 160'),
              Fact(FCategorie='Monastir'),
              Fact(FDomaine='Sciences de la santé,Médecine ,Médecine dentaire et Pharmacie'),
              Fact(FRegime='Préparatoire'),
              OR(Fact(FSexe='Masculin'),Fact(FSexe='Feminin')),
              OR(Fact(FAge='18 ans'),Fact(FAge='19 ans'))))
        def trouv_faculte10(self):
            test=True
            root1.minsize(500,300)
            img = PhotoImage(file="image/image_commun11.png")
            background= canvas1.create_image(250, 160,image=img)
            root1.mainloop()   
            
        @Rule(AND(OR(Fact(FSection='Mathematique'),Fact(FSection='Sciences Expérimentales')),
              Fact(FScore='entre 70 et 100'),
              Fact(FCategorie='Beja'),
              Fact(FDomaine='Sciences Agronomiques,Biotechnologie et Environnement'),
              Fact(FRegime='LMD'),
              OR(Fact(FSexe='Masculin'),Fact(FSexe='Feminin')),
              OR(Fact(FAge='18 ans'),Fact(FAge='19 ans'))))
        def trouv_faculte11(self):
            test=True                
            img = PhotoImage(file="image/biotechnologie_beja.png")
            background= canvas1.create_image(160, 160,image=img)
            root1.mainloop()   
            
        @Rule(AND(OR(Fact(FSection='Mathematique'),Fact(FSection='Sciences Expérimentales')),
              Fact(FScore='entre 130 et 160'),
              Fact(FCategorie='Tunis Manar'),
              Fact(FDomaine='Sciences Exactes et Technologies'),
              Fact(FRegime='Préparatoire'),
              OR(Fact(FSexe='Masculin'),Fact(FSexe='Feminin')),
              OR(Fact(FAge='18 ans'),Fact(FAge='19 ans'))))
        def trouv_faculte13(self):
            test=True                
            img = PhotoImage(file="image/fst.PNG")
            background= canvas1.create_image(160, 160,image=img)
            root1.mainloop()    
            
        @Rule(AND(Fact(FSection='Mathematique'),
              Fact(FScore='entre 130 et 160'),
              Fact(FCategorie='Zaghouan'),
              Fact(FDomaine='Education et Pédagogie'),
              Fact(FRegime='LMD'),
              OR(Fact(FSexe='Masculin'),Fact(FSexe='Feminin')),
              OR(Fact(FAge='18 ans'),Fact(FAge='19 ans'))))
        def trouv_faculte14(self):
            test=True 
            
            img = PhotoImage(file="image/zaghoun.PNG")
            background= canvas1.create_image(160, 160,image=img)
            root1.mainloop()  
            
        @Rule(AND(OR(Fact(FSection='Mathematique'),Fact(FSection='Sciences Expérimentales')),
              Fact(FScore='entre 130 et 160'),
              Fact(FCategorie='Tunis'),
              Fact(FDomaine='Sciences de la santé,Médecine ,Médecine dentaire et Pharmacie'),
              Fact(FRegime='LMD'),
              Fact(FSexe='Feminin'),
              OR(Fact(FAge='18 ans'),Fact(FAge='19 ans'))))
        def trouv_faculte15(self):
            test=True 
            img = PhotoImage(file="image/esstst.PNG")
            background= canvas1.create_image(160, 160,image=img)
            root1.mainloop()   
            
        @Rule(AND(OR(Fact(FSection='Mathematique'),Fact(FSection='Sciences Expérimentales')),
              Fact(FScore='supérieur à 160'),
              Fact(FCategorie='Carthage'),
              Fact(FDomaine='Sciences Exactes et Technologies'),
              Fact(FRegime='Préparatoire'),
              Fact(FSexe='Feminin'),
              Fact(FAge='18 ans')))
        def trouv_faculte14(self):
            test=True 
            img = PhotoImage(file="image/insat.PNG")
            background= canvas1.create_image(160, 160,image=img)
            root1.mainloop()   
            
        @Rule(AND(OR(Fact(FSection='Mathematique'),Fact(FSection='Sciences Expérimentales')),
              Fact(FScore='entre 70 et 100'),
              Fact(FCategorie='Nabeul'),
              Fact(FDomaine='Sciences Exactes et Technologies'),
              Fact(FRegime='LMD'),
              OR(Fact(FSexe='Masculin'),Fact(FSexe='Feminin')),
              Fact(FAge='18 ans')))
        def trouv_faculte15(self):
            test=True 
            img = PhotoImage(file="image/iset.PNG")
            background= canvas1.create_image(100,160,image=img)
            root1.mainloop() 
            
        @Rule(Fact(test==False))
        def erreur(self):
            img = PhotoImage(file="image/erreur404.png")
            background= canvas1.create_image(160,150,image=img)
            root1.mainloop()

    engine=tawjih()
    engine.reset() 
    engine.run()
    #root1.mainloop() 
Button(text="Résultat",font=("Courrier", 15),bg='#3C8DE5',fg='white',width=30,command=function_traitement).place(x=540,y=650)
root.mainloop()
# Out:
# Valeur change
# Valeur change
